# %%
import seaborn as sns
import pandas as pd

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips.time.value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
tips.time.value_counts().plot(kind='bar', xlabel='Time', ylabel='Number')
# Out:
# <Axes: xlabel='Time', ylabel='Number'>

# %%
tips.time.value_counts(normalize=True)
# Out:
# time
# Dinner    0.721311
# Lunch     0.278689
# Name: proportion, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean().plot.bar()
# Out:
# C:\Users\trive\AppData\Local\Temp\ipykernel_7280\516789996.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['time'])['tip'].mean().plot.bar()
# <Axes: xlabel='time'>

# %%
tips.time.value_counts().plot.bar()
# Out:
# <Axes: xlabel='time'>

# %%
tips.groupby(['smoker'])['tip'].mean()
# Out:
# C:\Users\trive\AppData\Local\Temp\ipykernel_7280\4002368646.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['smoker'])['tip'].mean()
# smoker
# Yes    3.008710
# No     2.991854
# Name: tip, dtype: float64

# %%
tips.groupby(['sex'])['tip'].mean()
# Out:
# C:\Users\trive\AppData\Local\Temp\ipykernel_7280\2844327552.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex'])['tip'].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
observed=False

# %%
tips.groupby(['day'])['tip'].mean()
# Out:
# C:\Users\trive\AppData\Local\Temp\ipykernel_7280\946538506.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['day'])['tip'].mean()
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64

# %%
tips.groupby(['size'])['tip'].mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
tips.groupby(['smoker', 'sex'])['tip'].mean().unstack()
# Out:
# C:\Users\trive\AppData\Local\Temp\ipykernel_7280\1637510694.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['smoker', 'sex'])['tip'].mean().unstack()
# sex         Male    Female
# smoker
# Yes     3.051167  2.931515
# No      3.113402  2.773519

# %%
tips['tip_pot'] = tips.tip / tips.total_bill

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pot
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
tips.plot.scatter(x= 'total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue= 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x='total_bill', y='tip', data=tips, col='sex', hue='time')

# %%
sns.displot(data=tips, x='total_bill', col='time', kde=True)

# %%
sns.pairplot(data=tips, hue='sex')
